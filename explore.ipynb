# %%
import os
import matplotlib.pyplot as plt
import PIL #pillow for loading images
import random

import torch
import torchvision.transforms
import torchvision.transforms.functional  #Compose

# %%
train_normal="data/chest_xray/train/NORMAL"
train_pneumonia="data/chest_xray/train/PNEUMONIA"

# %%
normal_images=os.listdir(train_normal)

# %%
random_normal_images=random.sample(normal_images,3)

# %%
from torchvision import transforms
transform_train = transforms.Compose([
    transforms.Lambda(lambda x: x.convert('RGB')),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
fig,axes=plt.subplots(1,3,figsize=(10,5))
i=0
for image in random_normal_images:
    img=PIL.Image.open(f"data/chest_xray/train/NORMAL/{image}")
    # transformed_img=transform(img)  
    axes[i].imshow(img,cmap='grey')
    #axes[i].axis('off')
    i=i+1

# %%
random_pneumonia_images=random.sample(pneumonia_images,3)

# %%
i=0
fig,axes=plt.subplots(1,3,figsize=(10,5))
for image in random_pneumonia_images:
    img=PIL.Image.open(f"data/chest_xray/train/PNEUMONIA/{image}")
    axes[i].imshow(img,cmap='grey')
    axes[i].axis('off')
    i=i+1

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[91], line 2
#       1 import torch
# ----> 2 print(torch.cuda.get_device_name(0))
#
# File c:\chest-xray-ai\venv\Lib\site-packages\torch\cuda\__init__.py:599, in get_device_name(device)
#     587 def get_device_name(device: "Device" = None) -> str:
#     588     r"""Get the name of a device.
#     589
#     590     Args:
#    (...)    597         str: the name of the device
#     598     """
# --> 599     return get_device_properties(device).name
#
# File c:\chest-xray-ai\venv\Lib\site-packages\torch\cuda\__init__.py:632, in get_device_properties(device)
#     620 def get_device_properties(device: "Device" = None) -> _CudaDeviceProperties:
#     621     r"""Get the properties of a device.
#     622
#     623     Args:
#    (...)    630         _CudaDeviceProperties: the properties of the device
#     631     """
# ...
